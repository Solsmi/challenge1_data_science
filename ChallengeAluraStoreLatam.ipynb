# %% [markdown]
# <a href="https://colab.research.google.com/github/Solsmi/challenge1_data_science/blob/main/ChallengeAluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Challenge 1 Data Science: Tiendas Juan

# %% [markdown]
# ##Extracción de datos

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# ##Análisis de datos

# %% [markdown]
# ###1. Análisis de facturación

# %% [markdown]
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
suma_total_precio = tienda["Precio"].sum()
suma_total_precio2 = tienda2["Precio"].sum()
suma_total_precio3 = tienda3["Precio"].sum()
suma_total_precio4 = tienda4["Precio"].sum()

# %%
print(f'La facturación total de la tienda 1 es: ${suma_total_precio}')
print(f'La facturación total de la tienda 2 es: ${suma_total_precio2}')
print(f'La facturación total de la tienda 3 es: ${suma_total_precio3}')
print(f'La facturación total de la tienda 4 es: ${suma_total_precio4}')
# Out:
# La facturación total de la tienda 1 es: $1150880400.0
# La facturación total de la tienda 2 es: $1116343500.0
# La facturación total de la tienda 3 es: $1098019600.0
# La facturación total de la tienda 4 es: $1038375700.0

# %% [markdown]
# ### 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
print("Ventas y Facturación por Categoría Tienda 1:")
ventas_y_facturacion_tienda1 = tienda.groupby('Categoría del Producto').agg(Total_Facturacion=('Precio', 'sum'), Cantidad_Ventas=('Producto', 'count')).sort_values(by='Cantidad_Ventas', ascending=False)
display(ventas_y_facturacion_tienda1)
print("\n")

print("Ventas y Facturación por Categoría Tienda 2:")
ventas_y_facturacion_tienda2 = tienda2.groupby('Categoría del Producto').agg(Total_Facturacion=('Precio', 'sum'), Cantidad_Ventas=('Producto', 'count')).sort_values(by='Cantidad_Ventas', ascending=False)
display(ventas_y_facturacion_tienda2)
print("\n")

print("Ventas y Facturación por Categoría Tienda 3:")
ventas_y_facturacion_tienda3 = tienda3.groupby('Categoría del Producto').agg(Total_Facturacion=('Precio', 'sum'), Cantidad_Ventas=('Producto', 'count')).sort_values(by='Cantidad_Ventas', ascending=False)
display(ventas_y_facturacion_tienda3)
print("\n")

print("Ventas y Facturación por Categoría Tienda 4:")
ventas_y_facturacion_tienda4 = tienda4.groupby('Categoría del Producto').agg(Total_Facturacion=('Precio', 'sum'), Cantidad_Ventas=('Producto', 'count')).sort_values(by='Cantidad_Ventas', ascending=False)
display(ventas_y_facturacion_tienda4)
# Out:
# Ventas y Facturación por Categoría Tienda 1:
#                          Total_Facturacion  Cantidad_Ventas
# Categoría del Producto
# Muebles                        187633700.0              465
# Electrónicos                   429493500.0              448
# Juguetes                        17995700.0              324
# Electrodomésticos              363685200.0              312
# Deportes y diversión            39290000.0              284
# Instrumentos musicales          91299000.0              182
# Libros                           8784900.0              173
# Artículos para el hogar         12698400.0              171
# Ventas y Facturación por Categoría Tienda 2:
#                          Total_Facturacion  Cantidad_Ventas
# Categoría del Producto
# Muebles                        176426300.0              442
# Electrónicos                   410831100.0              422
# Juguetes                        15945400.0              313
# ...

# %% [markdown]
# ### 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
calificacion_promedio_tienda1 = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()
print(f'La calificación promedio de la tienda 1 es: {calificacion_promedio_tienda1:.2f}')
print(f'La calificación promedio de la tienda 2 es: {calificacion_promedio_tienda2:.2f}')
print(f'La calificación promedio de la tienda 3 es: {calificacion_promedio_tienda3:.2f}')
print(f'La calificación promedio de la tienda 4 es: {calificacion_promedio_tienda4:.2f}')
# Out:
# La calificación promedio de la tienda 1 es: 3.98
# La calificación promedio de la tienda 2 es: 4.04
# La calificación promedio de la tienda 3 es: 4.05
# La calificación promedio de la tienda 4 es: 4.00

# %% [markdown]
# ### 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
def analizar_ventas_productos(df, nombre_tienda):
    ventas_productos = df['Producto'].value_counts()

    print(f"\n--- {nombre_tienda} ---")

    if not ventas_productos.empty:
        # Productos más vendidos
        print("Productos más vendidos:")
        top_n = min(5, len(ventas_productos))
        productos_mas_vendidos = ventas_productos.head(top_n).sort_values(ascending=False)
        for producto, cantidad in productos_mas_vendidos.items():
            print(f"  - {producto}: {cantidad} unidades")

        # Productos menos vendidos
        if len(ventas_productos) > 0:
            print("\nProductos menos vendidos:")
            bottom_n = min(3, len(ventas_productos))
            productos_menos_vendidos = ventas_productos.tail(bottom_n).sort_values(ascending=True)
            for producto, cantidad in productos_menos_vendidos.items():
                print(f"  - {producto}: {cantidad} unidades")
        else:
            print("No hay productos menos vendidos para analizar.")

    else:
        print("No hay datos de productos para analizar.")

analizar_ventas_productos(tienda, "Tienda 1")
analizar_ventas_productos(tienda2, "Tienda 2")
analizar_ventas_productos(tienda3, "Tienda 3")
analizar_ventas_productos(tienda4, "Tienda 4")
# Out:
# --- Tienda 1 ---
# Productos más vendidos:
#   - Microondas: 60 unidades
#   - TV LED UHD 4K: 60 unidades
#   - Armario: 60 unidades
#   - Secadora de ropa: 58 unidades
#   - Mesa de noche: 56 unidades
#
# Productos menos vendidos:
#   - Auriculares con micrófono: 33 unidades
#   - Celular ABXY: 33 unidades
#   - Olla de presión: 35 unidades
#
# --- Tienda 2 ---
# Productos más vendidos:
#   - Iniciando en programación: 65 unidades
#   - Microondas: 62 unidades
#   - Batería: 61 unidades
#   - Guitarra acústica: 58 unidades
#   - Pandereta: 58 unidades
#
# Productos menos vendidos:
#   - Juego de mesa: 32 unidades
#   - Mesa de comedor: 34 unidades
#   - Impresora: 34 unidades
#
# --- Tienda 3 ---
# Productos más vendidos:
#   - Kit de bancas: 57 unidades
#   - Mesa de comedor: 56 unidades
#   - Cama king: 56 unidades
#   - Set de ollas: 55 unidades
#   - Mesa de noche: 55 unidades
#
# Productos menos vendidos:
#   - Bloques de construcción: 35 unidades
#   - Mochila: 36 unidades
# ...

# %% [markdown]
# ### 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %%
costo_envio_promedio_tienda1 = tienda['Costo de envío'].mean()
costo_envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
costo_envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
costo_envio_promedio_tienda4 = tienda4['Costo de envío'].mean()
print(f'El costo de envío promedio de la tienda 1 es: ${costo_envio_promedio_tienda1:.2f}')
print(f'El costo de envío promedio de la tienda 2 es: ${costo_envio_promedio_tienda2:.2f}')
print(f'El costo de envío promedio de la tienda 3 es: ${costo_envio_promedio_tienda3:.2f}')
print(f'El costo de envío promedio de la tienda 4 es: ${costo_envio_promedio_tienda4:.2f}')
# Out:
# El costo de envío promedio de la tienda 1 es: $26018.61
# El costo de envío promedio de la tienda 2 es: $25216.24
# El costo de envío promedio de la tienda 3 es: $24805.68
# El costo de envío promedio de la tienda 4 es: $23459.46

# %% [markdown]
# ##Visualización

# %% [markdown]
# ###Generando gráfico

# %% [markdown]
# Después de realizar los análisis, es hora de transformar sus resultados en visualizaciones que le ayuden a comprender mejor los patrones y los insights encontrados.
#
# De acuerdo con funciones que haya creado, le recomendamos que genere al menos tres gráficos. Estos gráficos deben ser de diferentes tipos (como barras, líneas, dispersión, entre otros) para presentar una visión completa de los datos.
#
# Recuerde que los gráficos deben complementar el análisis realizado, resaltando los puntos más relevantes, como los ingresos de la tienda, la distribución de categorías de productos, las opiniones de los clientes, los productos más vendidos y/o los costes de envío.
#
# No es necesario mostrar una visualización en cada paso, pero al final del análisis debes generar los gráficos que consideres más útiles para interpretar los datos.
#
# Consejo: Matplotlib ofrece una variedad de tipos de gráficos que son fáciles de implementar, lo que lo convierte en una excelente opción para principiantes. Utilice su creatividad para elegir los gráficos que mejor resalten las tendencias y los conocimientos de su análisis.

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ####**Ingresos totales por tienda**

# %%
import matplotlib.ticker as mticker

nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
facturacion_total = [suma_total_precio, suma_total_precio2, suma_total_precio3, suma_total_precio4]

# Generar el gráfico de barras simple
plt.figure(figsize=(10, 6))
plt.bar(nombres_tiendas, facturacion_total, color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
plt.xlabel('Tiendas')
plt.ylabel('Facturación Total ($)')
plt.title('Facturación Total por Tienda')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Formato con separador de miles
plt.gca().yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %% [markdown]
# ####**Ventas por categoría**

# %%
import seaborn as sns

# Preparar los datos para la comparación
ventas_y_facturacion_tienda1['Tienda'] = 'Tienda 1'
ventas_y_facturacion_tienda2['Tienda'] = 'Tienda 2'
ventas_y_facturacion_tienda3['Tienda'] = 'Tienda 3'
ventas_y_facturacion_tienda4['Tienda'] = 'Tienda 4'

# Resetear el índice para que 'Categoría del Producto' sea una columna antes de concatenar
df_tienda1 = ventas_y_facturacion_tienda1.reset_index()
df_tienda2 = ventas_y_facturacion_tienda2.reset_index()
df_tienda3 = ventas_y_facturacion_tienda3.reset_index()
df_tienda4 = ventas_y_facturacion_tienda4.reset_index()

# Concatenar todos los DataFrames en uno solo para la visualización comparativa
ventas_comparativas = pd.concat([df_tienda1, df_tienda2, df_tienda3, df_tienda4])

# Generar el gráfico de barras agrupadas
plt.figure(figsize=(15, 8))
sns.barplot(
    data=ventas_comparativas,
    x='Categoría del Producto',
    y='Cantidad_Ventas',
    hue='Tienda',
    palette='viridis'
)

plt.title('Comparación de Cantidad de Ventas por Categoría según Tienda')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad de Ventas')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Tienda')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
